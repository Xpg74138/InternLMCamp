# %% [markdown]
# # 基础作业

# %% [markdown]
# 要实现“通过微调，帮助模型认清了解对自己身份弟位”的目的和之前教程中的"区别"就是要修改数据集，你要去告诉模型他是谁,下面是最终的一个效果

# %% [markdown]
# 在修改batch_size=8之后训练得到的结果，似乎并不是很好，没太懂为什么？

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 还是将batch_size改回2，继续训练，效果似乎不错

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 还有个小问题就是按教程走完会报错，这是由web_demo.py中的76，77行的图片的路径导致，要修改成绝对路径

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# # 进阶作业
