# %% [markdown]
# ## 1.使用 InternLM-Chat-7B 模型生成 300 字的小故事

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 2.熟悉 hugging face 下载功能，使用 huggingface_hub python 包，下载 InternLM-20B 的 config.json 文件到本地

# %% [markdown]
# 代码部分

# %%
import os
os.system('pip install -U huggingface_hub')
# Out:
# 0

# %%
from huggingface_hub import hf_hub_download  
hf_hub_download(repo_id="internlm/internlm-20b", filename="config.json")

# %% [markdown]
# 这里直接下载会有网络问题，于是换了镜像网站，成功下载

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 3.浦语·灵笔的图文理解及创作部署

# %% [markdown]
# 图文创作能力

# %% [markdown]
# ![31c7113f84094e86b8cdc3da62b9eb09.png](attachment:31c7113f84094e86b8cdc3da62b9eb09.png)

# %% [markdown]
# 多模态对话能力，模型有点倔强的

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 4.Lagent 工具调用 Demo 创作部署

# %% [markdown]
# ![image.png](attachment:image.png)
